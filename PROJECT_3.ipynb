# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
#UPLOADED DATASET

# %%
file_path="/content/housing_data.csv"
df1=pd.read_csv(file_path, index_col=0)
df1
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          SC60       RL           65     8450   Pave   NaN      Reg
# 1          SC20       RL           80     9600   Pave   NaN      Reg
# 2          SC60       RL           68    11250   Pave   NaN      IR1
# 3          SC70       RL           60     9550   Pave   NaN      IR1
# 4          SC60       RL           84    14260   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455       SC60       RL           62     7917   Pave   NaN      Reg
# 1456       SC20       RL           85    13175   Pave   NaN      Reg
# 1457       SC70       RL           66     9042   Pave   NaN      Reg
# 1458       SC20       RL           68     9717   Pave   NaN      Reg
# 1459       SC20       RL           75     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df1.shape
# Out:
# (1460, 80)

# %%
df1.drop_duplicates
df1
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          SC60       RL           65     8450   Pave   NaN      Reg
# 1          SC20       RL           80     9600   Pave   NaN      Reg
# 2          SC60       RL           68    11250   Pave   NaN      IR1
# 3          SC70       RL           60     9550   Pave   NaN      IR1
# 4          SC60       RL           84    14260   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455       SC60       RL           62     7917   Pave   NaN      Reg
# 1456       SC20       RL           85    13175   Pave   NaN      Reg
# 1457       SC70       RL           66     9042   Pave   NaN      Reg
# 1458       SC20       RL           68     9717   Pave   NaN      Reg
# 1459       SC20       RL           75     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
#Countplot for Building Type for categorical data

# %%
sns.countplot(df1['BldgType'])
# Out:
# <Axes: xlabel='count', ylabel='BldgType'>

# %%
#Countplot for Building Type for Numerical data

# %%
import matplotlib.pyplot as plt
plt.hist(df1['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
#Kernal Density

# %%
sns.distplot(df1['SalePrice'])
# Out:
# /tmp/ipython-input-15-2646407341.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['SalePrice'])
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
sns.boxplot(df1['SalePrice'])
# Out:
# <Axes: ylabel='SalePrice'>

# %%
df1['SalePrice'].min()
# Out:
# 34900

# %%
df1['SalePrice'].max()
# Out:
# 755000

# %%
df1['SalePrice'].mean()
# Out:
# np.float64(180921.19589041095)

# %%
df1['SalePrice'].skew()
# Out:
# np.float64(1.8828757597682129)

# %%
#Multivariate Analysis#Scatterplot (Numerical-Numerical)

# %%
iris = sns.load_dataset("iris")

# %%
sns.scatterplot(data=df1, x="LotArea", y="SalePrice")
# Out:
# <Axes: xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.scatterplot(data=df1, x="SalePrice", y="HouseStyle")
# Out:
# <Axes: xlabel='SalePrice', ylabel='HouseStyle'>

# %%
#Multivarient Analysis#Scatterplot (Numerical-Numerical)using 3 different variables

# %%
sns.scatterplot(data=df1, x="SalePrice", y="HouseStyle", hue="BldgType")
# Out:
# <Axes: xlabel='SalePrice', ylabel='HouseStyle'>

# %%
#check the relation between year the house sold and Sales price using median value

# %%
df2=df2.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median SalePrice')
plt.title('Median SalePrice by Year Sold')
plot = plt.show()
